# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
url="https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv"
baby_names=pd.read_csv(url)
baby_names.head()
# Out:
#    Unnamed: 0     Id     Name  Year Gender State  Count
# 0       11349  11350     Emma  2004      F    AK     62
# 1       11350  11351  Madison  2004      F    AK     48
# 2       11351  11352   Hannah  2004      F    AK     46
# 3       11352  11353    Grace  2004      F    AK     44
# 4       11353  11354    Emily  2004      F    AK     41

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names=baby_names.drop(['Unnamed: 0','Id'],axis=1)
baby_names
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %% [markdown]
# ### Step 6. Is there more male or female names in the dataset?

# %%
baby_names["Gender"].value_counts()
# Out:
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
names=baby_names.groupby("Name") #doesnot show any output result
print(names)

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
print("No of different names are: ",len(names))
for key,item in names:
    print(key)
# Out:
# No of different names are:  17632
# Aaban
# Aadan
# Aadarsh
# Aaden
# Aadhav
# Aadhya
# Aadi
# Aadin
# Aadit
# Aaditya
# Aadya
# Aadyn
# Aahan
# Aahana
# Aahil
# Aahna
# Aaiden
# Aaima
# Aakash
# Aalaya
# Aalayah
# Aaleah
# Aaleyah
# Aalia
# Aaliah
# Aalijah
# Aaliya
# Aaliyah
# Aaliyha
# Aalyah
# Aalyiah
# Aamina
# Aaminah
# Aamir
# Aamira
# Aamiyah
# Aanika
# Aaniya
# Aaniyah
# Aanya
# Aaradhya
# Aaralyn
# Aaralynn
# Aarav
# Aaren
# Aaria
# Aarian
# Aariana
# Aaric
# Aarika
# Aarin
# Aarini
# Aarion
# Aariv
# Aariyah
# Aariz
# Aarna
# Aarnav
# Aarohi
# Aaron
# Aaronjames
# Aarron
# Aarush
# Aarushi
# Aarvi
# Aarya
# Aaryan
# Aaryav
# Aaryn
# Aasha
# Aashi
# Aashna
# Aashritha
# Aashvi
# Aasia
# Aasim
# Aasiyah
# Aastha
# Aayan
# Aayansh
# Aayat
# Aayden
# Aayla
# Aayush
# Ab
# Abagail
# Abanoub
# Abba
# Abbagail
# Abbas
# Abbey
# Abbi
# Abbie
# Abbiegail
# Abbigail
# Abbigale
# Abbigayle
# Abbott
# Abby
# Abbygail
# Abbygale
# Abbygayle
# Abcde
# Abdalla
# Abdallah
# Abdel
# ...

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
names=baby_names.groupby("Name").count()
names.sort_values('Count',ascending=False)['Count'].head(5)
# Out:
# Name
# Riley     1112
# Avery     1080
# Jordan    1073
# Peyton    1064
# Hayden    1049
# Name: Count, dtype: int64

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
names[names['Count']==names["Count"].min()]
# Out:
#             Year  Gender  State  Count
# Name
# Aadarsh        1       1      1      1
# Aadhav         1       1      1      1
# Aadin          1       1      1      1
# Aahna          1       1      1      1
# Aaima          1       1      1      1
# ...          ...     ...    ...    ...
# Zykeriah       1       1      1      1
# Zykierra       1       1      1      1
# Zymari         1       1      1      1
# Zyquavious     1       1      1      1
# Zyren          1       1      1      1
#
# [3682 rows x 4 columns]

# %%
len(names[names['Count']==names["Count"].min()])
# Out:
# 3682

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
names[names['Count']==names["Count"].median()]
# Out:
#           Gender  State  Count
# Name
# Abubakar       8      8      8
# Adelie         8      8      8
# Adira          8      8      8
# Adylene        8      8      8
# Aerial         8      8      8
# ...          ...    ...    ...
# Zamaya         8      8      8
# Zanaya         8      8      8
# Zari           8      8      8
# Zaylie         8      8      8
# Zyanna         8      8      8
#
# [360 rows x 3 columns]

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %%
names["Count"].std() #shouldn't match with any data...just a standard deviation of the count of names
# Out:
# 122.02996350814125

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.

# %%
names["Count"].agg(['mean','min','max','std'])
# Out:
# mean      57.644907
# min        1.000000
# max     1112.000000
# std      122.029964
# Name: Count, dtype: float64

# %%
names['Count'].describe()
# Out:
# count    17632.000000
# mean        57.644907
# std        122.029964
# min          1.000000
# 25%          2.000000
# 50%          8.000000
# 75%         39.000000
# max       1112.000000
# Name: Count, dtype: float64
